# %%
# !pip install tabula-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 6.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#   Using cached distro-1.8.0-py3-none-any.whl (20 kB)
# ...

# %%
import tabula
area = [70, 30, 1000, 570] # Seems to have to be done manually
page2 = tabula.read_pdf("Input_Documents/Ambit_HDFC Life_FY23.pdf", guess=True, lattice=False, 
                 stream=False, multiple_tables=True, area=area, pages="all",output_format="json"
                   ) # `tabula` doc explains params very well
page2[0]
# Out:
# Got stderr: Jul 27, 2023 8:50:48 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Jul 27, 2023 8:50:48 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
# {'extraction_method': 'stream',
#  'top': 70.0,
#  'left': 30.0,
#  'width': 540.0,
#  'height': 930.0,
#  'right': 570.0,
#  'bottom': 1000.0,
#  'data': [[{'top': 95.36,
#     'left': 32.15,
#     'width': 322.5899963378906,
#     'height': 7.019999980926514,
#     'text': 'ad to APE growth passes through HDFC Bank'},
#    {'top': 97.52,
#     'left': 421.27,
#     'width': 148.59002685546875,
#     'height': 10.5,
#     'text': 'Results Update'}],
#   [{'top': 116.36,
#     'left': 33.7,
#     'width': 372.9100036621094,
#     'height': 4.980000019073486,
#     'text': 'QFY23, APE/VNB were 29%/30% above our forecast due to stronger-than-'},
# ...
